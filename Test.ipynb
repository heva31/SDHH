# %%
import folium

# Create a base map centered at initial coordinates (latitude, longitude)
m = folium.Map(location=[0, 0], zoom_start=2)

# Example: Add a marker to specific coordinates
folium.Marker(location=[37.7749, -122.4194], popup='San Francisco').add_to(m)
folium.Marker(location=[51.5074, -0.1278], popup='London').add_to(m)

# Save map as an HTML file or display inline (if using Jupyter Notebook)
m.save("world_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dac56005de61578d187ee2d35a23e34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dac56005de61578d187ee2d35a23e34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dac56005de61578d187ee2d35a23e34 = L.map(
#                 &quot;map_6dac56005de61578d187ee2d35a23e34&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7694dc757d5b08f0ac877e7b5685344 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7694dc757d5b08f0ac877e7b5685344.addTo(map_6dac56005de61578d187ee2d35a23e34);
#
#
#             var marker_2d1076d6d5fcb4882cddc189633429a5 = L.marker(
#                 [37.7749, -122.4194],
#                 {
# }
#             ).addTo(map_6dac56005de61578d187ee2d35a23e34);
#
#
#         var popup_9490360ec9b0d33a2e632a88179cc7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64de3765aeebfa5391013290ce800198 = $(`&lt;div id=&quot;html_64de3765aeebfa5391013290ce800198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_9490360ec9b0d33a2e632a88179cc7fb.setContent(html_64de3765aeebfa5391013290ce800198);
#
#
#
#         marker_2d1076d6d5fcb4882cddc189633429a5.bindPopup(popup_9490360ec9b0d33a2e632a88179cc7fb)
#         ;
#
#
#
#
#             var marker_5942b1f76bfd138ad1a246999693feb9 = L.marker(
#                 [51.5074, -0.1278],
#                 {
# }
#             ).addTo(map_6dac56005de61578d187ee2d35a23e34);
#
#
#         var popup_f060367bc90ddae8adc54d4fbaad4dc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de633c6cd741775ee6f1b2b4eca41010 = $(`&lt;div id=&quot;html_de633c6cd741775ee6f1b2b4eca41010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London&lt;/div&gt;`)[0];
#                 popup_f060367bc90ddae8adc54d4fbaad4dc3.setContent(html_de633c6cd741775ee6f1b2b4eca41010);
#
#
#
#         marker_5942b1f76bfd138ad1a246999693feb9.bindPopup(popup_f060367bc90ddae8adc54d4fbaad4dc3)
#         ;
#
#
#
#
#             tile_layer_b7694dc757d5b08f0ac877e7b5685344.addTo(map_6dac56005de61578d187ee2d35a23e34);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !py -3.12 -m pip install folium geopy
# Out:
# Requirement already satisfied: folium in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (0.19.5)
# Requirement already satisfied: geopy in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (2.4.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from folium) (2025.1.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from geopy) (2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shubham\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2024.7.4)

# %%
import folium
from folium.plugins import Search

# Create a base map centered at initial coordinates (latitude, longitude)
m = folium.Map(location=[20, 0], zoom_start=2)

# Add marker data for different cities (you can add more points)
city_data = {
    "San Francisco": [37.7749, -122.4194],
    "London": [51.5074, -0.1278],
    "Tokyo": [35.6895, 139.6917],
    "New York": [40.7128, -74.0060],
}

# Add each city to the map
for city, coord in city_data.items():
    folium.Marker(location=coord, popup=city).add_to(m)

# Add a search control that looks for cities on the map
search_layer = folium.FeatureGroup(name="Cities").add_to(m)
for city, coord in city_data.items():
    folium.Marker(location=coord, popup=city).add_to(search_layer)

Search(layer=search_layer, search_label="name").add_to(m)

# Save and display the map
m.save("searchable_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cca8dc9f17b77a308780f31aef4dba7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cca8dc9f17b77a308780f31aef4dba7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cca8dc9f17b77a308780f31aef4dba7 = L.map(
#                 &quot;map_8cca8dc9f17b77a308780f31aef4dba7&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_823c42c437c6be76f10ce8d056e3291b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_823c42c437c6be76f10ce8d056e3291b.addTo(map_8cca8dc9f17b77a308780f31aef4dba7);
#
#
#             var marker_357da2a1d3c3244bdc7808e161038efa = L.marker(
#                 [37.7749, -122.4194],
#                 {
# }
#             ).addTo(map_8cca8dc9f17b77a308780f31aef4dba7);
#
#
#         var popup_0acd54319b338c5f070747b7761e4f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbb4e6f4d7eb5415c449be902dae7948 = $(`&lt;div id=&quot;html_dbb4e6f4d7eb5415c449be902dae7948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_0acd54319b338c5f070747b7761e4f7a.setContent(html_dbb4e6f4d7eb5415c449be902dae7948);
#
#
#
#         marker_357da2a1d3c3244bdc7808e161038efa.bindPopup(popup_0acd54319b338c5f070747b7761e4f7a)
#         ;
#
#
#
#
#             var marker_f61bc0bd2c180dc2707bb661a84245a2 = L.marker(
#                 [51.5074, -0.1278],
#                 {
# }
#             ).addTo(map_8cca8dc9f17b77a308780f31aef4dba7);
#
#
#         var popup_a2ecc02ca61a7d089cb6322b51756cf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be11a852c7e0934478256456a27f90c5 = $(`&lt;div id=&quot;html_be11a852c7e0934478256456a27f90c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London&lt;/div&gt;`)[0];
#                 popup_a2ecc02ca61a7d089cb6322b51756cf8.setContent(html_be11a852c7e0934478256456a27f90c5);
#
#
#
#         marker_f61bc0bd2c180dc2707bb661a84245a2.bindPopup(popup_a2ecc02ca61a7d089cb6322b51756cf8)
#         ;
#
#
#
#
#             var marker_1fb6d2dd2a7c111bca432510cdb40fae = L.marker(
#                 [35.6895, 139.6917],
#                 {
# }
#             ).addTo(map_8cca8dc9f17b77a308780f31aef4dba7);
#
#
#         var popup_565f59c44b8539a8e9a5035b84349fa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0a55759da4ddb5e75629cd5a5cd9e3c = $(`&lt;div id=&quot;html_b0a55759da4ddb5e75629cd5a5cd9e3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo&lt;/div&gt;`)[0];
#                 popup_565f59c44b8539a8e9a5035b84349fa8.setContent(html_b0a55759da4ddb5e75629cd5a5cd9e3c);
#
#
#
#         marker_1fb6d2dd2a7c111bca432510cdb40fae.bindPopup(popup_565f59c44b8539a8e9a5035b84349fa8)
#         ;
#
#
#
#
#             var marker_aebe0eec314ae6f6d2405af41209d4d7 = L.marker(
#                 [40.7128, -74.006],
#                 {
# }
#             ).addTo(map_8cca8dc9f17b77a308780f31aef4dba7);
#
#
#         var popup_2387de911f2f9302cf9434fdd1bab61e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d41a2b02636416fc64512509301bf563 = $(`&lt;div id=&quot;html_d41a2b02636416fc64512509301bf563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_2387de911f2f9302cf9434fdd1bab61e.setContent(html_d41a2b02636416fc64512509301bf563);
#
#
#
#         marker_aebe0eec314ae6f6d2405af41209d4d7.bindPopup(popup_2387de911f2f9302cf9434fdd1bab61e)
#         ;
#
#
#
#
#             var feature_group_9ad08164be6018654557a402433851d1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9bc08c6a2b4c10e844bd4c7e6d4fe4e8 = L.marker(
#                 [37.7749, -122.4194],
#                 {
# }
#             ).addTo(feature_group_9ad08164be6018654557a402433851d1);
#
#
#         var popup_44b17e1f5715e82be561f4f6a94e1783 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f6bb74bfab5f3f07f0e780e9aa76003 = $(`&lt;div id=&quot;html_1f6bb74bfab5f3f07f0e780e9aa76003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popu

# %%
import folium
from folium.plugins import Search

# Create a base map centered at initial coordinates
m = folium.Map(location=[20, 0], zoom_start=2)

# Create a FeatureGroup to hold the city markers with searchable properties
city_group = folium.FeatureGroup(name="Cities")

# Sample city data with coordinates
city_data = {
    "San Francisco": [37.7749, -122.4194],
    "London": [51.5074, -0.1278],
    "Tokyo": [35.6895, 139.6917],
    "New York": [40.7128, -74.0060],
}

# # Add each city as a GeoJSON-like feature with 'name' property
# for city, coord in city_data.items():
#     folium.Marker(
#         location=coord,
#         popup=f"City: {city}",
#         icon=folium.Icon(color="blue"),
#     ).add_to(city_group)

# Attach properties to each city for searching
geojson_data = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"name": city},
            "geometry": {
                "type": "Point",
                "coordinates": [coord[1], coord[0]],  # lon, lat order in GeoJSON
            },
        }
        for city, coord in city_data.items()
    ],
}

# Add searchable GeoJSON to the map
geojson_layer = folium.GeoJson(geojson_data, name="City Layer").add_to(m)

# Add the search functionality on the map with the 'name' property from GeoJSON
Search(layer=geojson_layer, search_label="name", placeholder="Search for a city").add_to(m)

# Add both layers to the map
m.add_child(city_group)

m.add_child(folium.LatLngPopup())


# Save and display the map
m.save("searchable_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53404a6ca317de0a9e50bf7261dc143b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53404a6ca317de0a9e50bf7261dc143b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53404a6ca317de0a9e50bf7261dc143b = L.map(
#                 &quot;map_53404a6ca317de0a9e50bf7261dc143b&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f6fd9fd6920b983f9deb970c3508ee9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f6fd9fd6920b983f9deb970c3508ee9.addTo(map_53404a6ca317de0a9e50bf7261dc143b);
#
#
#
#         function geo_json_5b0a79cd6e8d382cfee52c2f49811179_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5b0a79cd6e8d382cfee52c2f49811179 = L.geoJson(null, {
#                 onEachFeature: geo_json_5b0a79cd6e8d382cfee52c2f49811179_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_5b0a79cd6e8d382cfee52c2f49811179_add (data) {
#             geo_json_5b0a79cd6e8d382cfee52c2f49811179
#                 .addData(data);
#         }
#             geo_json_5b0a79cd6e8d382cfee52c2f49811179_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.4194, 37.7749], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;San Francisco&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-0.1278, 51.5074], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;London&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [139.6917, 35.6895], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Tokyo&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-74.006, 40.7128], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;New York&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_5b0a79cd6e8d382cfee52c2f49811179.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_5b0a79cd6e8d382cfee52c2f49811179.addTo(map_53404a6ca317de0a9e50bf7261dc143b);
#
#
#             var geo_json_5b0a79cd6e8d382cfee52c2f49811179searchControl = new L.Control.Search({
#                 layer: geo_json_5b0a79cd6e8d382cfee52c2f49811179,
#
#                 propertyName: &#x27;name&#x27;,
#
#                 collapsed: false,
#                 textPlaceholder: &#x27;Search for a city&#x27;,
#                 position:&#x27;topleft&#x27;,
#
#                 initial: false,
#
#                 hideMarkerOnCollapse: true
#
#                 });
#                 geo_json_5b0a79cd6e8d382cfee52c2f49811179searchControl.on(&#x27;search:locationfound&#x27;, function(e) {
#                     geo_json_5b0a79cd6e8d382cfee52c2f49811179.setStyle(function(feature){
#                         return feature.properties.style
#                     })
#
#                     if(e.layer._popup)
#                         e.layer.openPopup();
#                 })
#                 geo_json_5b0a79cd6e8d382cfee52c2f49811179searchControl.on(&#x27;search:collapsed&#x27;, function(e) {
#                         geo_json_5b0a79cd6e8d382cfee52c2f49811179.setStyle(function(feature){
#                             return feature.properties.style
#                     });
#                 });
#             map_53404a6ca317de0a9e50bf7261dc143b.addControl( geo_json_5b0a79cd6e8d382cfee52c2f49811179searchControl );
#
#
#
#             var feature_group_f990459fa3f56bb394322f8e6cf6ecc8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f990459fa3f56bb394322f8e6cf6ecc8.addTo(map_53404a6ca317de0a9e50bf7261dc143b);
#
#
#                 var lat_lng_popup_d5fb2b21af518c1d7c957b54dd45b77f = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_d5fb2b21af518c1d7c957b54dd45b77f
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_53404a6ca317de0a9e5

# %%
import folium
from folium.plugins import Search

# Create the base map
m = folium.Map(location=[20, 0], zoom_start=2)

# Sample city data
city_data = {
    "San Francisco": [37.7749, -122.4194],
    "London": [51.5074, -0.1278],
    "Tokyo": [35.6895, 139.6917],
    "New York": [40.7128, -74.0060],
}

# Create GeoJSON data for cities with searchable properties
geojson_data = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"name": city},  # Attach 'name' for search
            "geometry": {
                "type": "Point",
                "coordinates": [coord[1], coord[0]],  # lon, lat order for GeoJSON
            },
        }
        for city, coord in city_data.items()
    ],
}

# Add GeoJSON layer with markers to the map (enabling search by 'name')
geojson_layer = folium.GeoJson(
    geojson_data,
    name="Cities",
    popup=folium.GeoJsonPopup(fields=["name"]),
).add_to(m)

# Add Search bar with search based on 'name'
search = Search(
    layer=geojson_layer,
    search_label="name",
    placeholder="Search for a city...",
).add_to(m)

# Add JavaScript to display lat/lon on click anywhere on the map
m.get_root().html.add_child(folium.Element("""
<script>
document.addEventListener("DOMContentLoaded", function() {
    let map = document.querySelector(".leaflet-container")._leaflet_map;
    map.on('click', function(e) {
        alert("Latitude: " + e.latlng.lat + "\\nLongitude: " + e.latlng.lng);
    });
});
</script>
"""))

# Save the map as HTML and display it
m.save("search_with_latlon.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37b69ea0a58e18832b28b018bd44b334 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;script&gt;
# document.addEventListener(&quot;DOMContentLoaded&quot;, function() {
#     let map = document.querySelector(&quot;.leaflet-container&quot;)._leaflet_map;
#     map.on(&#x27;click&#x27;, function(e) {
#         alert(&quot;Latitude: &quot; + e.latlng.lat + &quot;\nLongitude: &quot; + e.latlng.lng);
#     });
# });
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37b69ea0a58e18832b28b018bd44b334&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37b69ea0a58e18832b28b018bd44b334 = L.map(
#                 &quot;map_37b69ea0a58e18832b28b018bd44b334&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be054404eb4f3f90c130f05b2558e027 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be054404eb4f3f90c130f05b2558e027.addTo(map_37b69ea0a58e18832b28b018bd44b334);
#
#
#
#         function geo_json_f7dd3c8d91cd59b1b082e4560235db4a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f7dd3c8d91cd59b1b082e4560235db4a = L.geoJson(null, {
#                 onEachFeature: geo_json_f7dd3c8d91cd59b1b082e4560235db4a_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_f7dd3c8d91cd59b1b082e4560235db4a_add (data) {
#             geo_json_f7dd3c8d91cd59b1b082e4560235db4a
#                 .addData(data);
#         }
#             geo_json_f7dd3c8d91cd59b1b082e4560235db4a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.4194, 37.7749], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;San Francisco&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-0.1278, 51.5074], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;London&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [139.6917, 35.6895], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Tokyo&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-74.006, 40.7128], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;New York&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_f7dd3c8d91cd59b1b082e4560235db4a.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#     geo_json_f7dd3c8d91cd59b1b082e4560235db4a.bindPopup(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     let handleObject = feature=&gt;typeof(feature)==&#x27;object&#x27; ? JSON.stringify(feature) : feature;
#     let fields = [&quot;name&quot;];
#     let aliases = [&quot;name&quot;];
#     let table = &#x27;&lt;table&gt;&#x27; +
#         String(
#         fields.map(
#         (v,i)=&gt;
#         `&lt;tr&gt;
#             &lt;th&gt;${aliases[i].toLocaleString()}&lt;/th&gt;
#
#             &lt;td&gt;${handleObject(layer.feature.properties[v]).toLocaleString()}&lt;/td&gt;
#         &lt;/tr&gt;`).join(&#x27;&#x27;))
#     +&#x27;&lt;/table&gt;&#x27;;
#     div.innerHTML=table;
#
#     return div
#     }
#     ,{
#   &quot;className&quot;: &quot;foliumpopup&quot;,
# });
#
#
#             geo_json_f7dd3c8d91cd59b1b082e4560235db4a.addTo(map_37b69ea0a58e18832b28b018bd44b334);
#
#
#             var geo_json_f7dd3c8d91cd59b1b082e4560235db4asearchControl = new L.Control.Search({
#                 layer: geo_json_f7dd3c8d91cd59b1b082e4560235db4a,
#
#                 propertyName: &#x27;name&#x27;,
#
#                 collapsed: false,
#                 textPlaceholder: &#x27;Search for a city...&#x27;,
#                 position:&#x27;topleft&#x27;,

# %%
import folium

# Create a world map
world_map = folium.Map(location=[20, 0], zoom_start=2)

# Add a click event to show coordinates
world_map.add_child(folium.LatLngPopup())

# Save and display the map
world_map.save("world_map.html")
print("Map has been saved. Open world_map.html in a browser.")
# Out:
# Map has been saved. Open world_map.html in a browser.

# %%
from geopy.geocoders import Nominatim

# Initialize geocoder
geolocator = Nominatim(user_agent="geo_locator")

# Function to get coordinates
def get_coordinates(place):
    location = geolocator.geocode(place)
    if location:
        return location.latitude, location.longitude
    else:
        return None

# Example Usage
place = input("Enter a place name: ")
coordinates = get_coordinates(place)

if coordinates:
    print(f"Coordinates of {place}: {coordinates}")
    # Add a marker on the map
    folium.Marker(location=coordinates, popup=place, icon=folium.Icon(color="blue")).add_to(world_map)
    world_map.save("world_map_with_marker.html")
    print("Updated map with marker saved as world_map_with_marker.html")
else:
    print("Location not found.")
# Out:
# Coordinates of Tokoy: (40.1375551, 71.0841394)
# Updated map with marker saved as world_map_with_marker.html

# %%
import folium

# Create the base map
m = folium.Map(location=[20, 0], zoom_start=2)

# Add JavaScript to capture clicks and show coordinates in an alert
click_js = """
<script>
document.addEventListener("DOMContentLoaded", function() {
    let map = document.querySelector(".leaflet-container")._leaflet_map;
    map.on('click', function(e) {
        alert("Latitude: " + e.latlng.lat + "\\nLongitude: " + e.latlng.lng);
    });
});
</script>
"""

# Attach JavaScript to the map
m.get_root().html.add_child(folium.Element(click_js))

# Save and display the map
m.save("clickable_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1e69212e7c8533728f81023bb0d83cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;script&gt;
# document.addEventListener(&quot;DOMContentLoaded&quot;, function() {
#     let map = document.querySelector(&quot;.leaflet-container&quot;)._leaflet_map;
#     map.on(&#x27;click&#x27;, function(e) {
#         alert(&quot;Latitude: &quot; + e.latlng.lat + &quot;\nLongitude: &quot; + e.latlng.lng);
#     });
# });
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1e69212e7c8533728f81023bb0d83cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1e69212e7c8533728f81023bb0d83cd = L.map(
#                 &quot;map_d1e69212e7c8533728f81023bb0d83cd&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1f441e15e6436e58a17268f013a01bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1f441e15e6436e58a17268f013a01bb.addTo(map_d1e69212e7c8533728f81023bb0d83cd);
#
#
#             tile_layer_c1f441e15e6436e58a17268f013a01bb.addTo(map_d1e69212e7c8533728f81023bb0d83cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Set a specific latitude and longitude (Example: New York)
latitude = 23.0025 
longitude = 72.6111

# Create a map centered at the specific location
m = folium.Map(location=[latitude, longitude], zoom_start=100)

# Add a marker at the specific location
# folium.Marker([latitude, longitude], popup="New York", tooltip="Click for details").add_to(m)

# Save the map
m.save("centered_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bed91e43dd1c6aa8292d99505a667112 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bed91e43dd1c6aa8292d99505a667112&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bed91e43dd1c6aa8292d99505a667112 = L.map(
#                 &quot;map_bed91e43dd1c6aa8292d99505a667112&quot;,
#                 {
#                     center: [23.0025, 72.6111],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 100,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_416cacf48976cc73508ae99911952020 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_416cacf48976cc73508ae99911952020.addTo(map_bed91e43dd1c6aa8292d99505a667112);
#
#
#             tile_layer_416cacf48976cc73508ae99911952020.addTo(map_bed91e43dd1c6aa8292d99505a667112);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
